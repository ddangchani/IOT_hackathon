# %% [markdown]
# # 서울시 상권분석서비스 데이터 전처리
# - 상권 도로명주소를 geocoding하여 (`geopy` 이용) 도로명주소 좌표로 전처리

# %%
# For Google Colab
from google.colab import drive
drive.mount('/content/Mydrive')
# %cd "/content/Mydrive/MyDrive/IOT_hackathon/Github/IOT_hackathon"
# Out:
# Mounted at /content/Mydrive
# /content/Mydrive/MyDrive/IOT_hackathon/Github/IOT_hackathon

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import numpy as np
from tqdm import tqdm

# %%
df = pd.read_csv('data/서울시_우리마을가게_상권분석서비스(구_상권_생활인구)_2021년.csv', encoding = 'cp949')
df.head(5) # 5980 rows * 532 columns
# Out:
#    기준 년코드  기준_분기_코드 상권_구분_코드  상권_구분_코드_명    상권_코드   상권_코드_명  총_생활인구_수  \
# 0    2021         1        A        골목상권  1000001       계동길    282796
# 1    2021         1        A        골목상권  1000002    난계로27길    320864
# 2    2021         1        A        골목상권  1000003  돈화문로11가길    162400
# 3    2021         1        A        골목상권  1000004       명륜길    626489
# 4    2021         1        A        골목상권  1000005      백석동길    172515
#
#    남성_생활인구_수  여성_생활인구_수  연령대_10_생활인구_수  ...  여성연령대_60_이상_토요일시간대_3_생활인구_수  \
# 0     142207     140590          34007  ...                          603
# 1     164461     156403          16361  ...                          900
# 2      90505      71895           9073  ...                          343
# 3     297916     328574          82087  ...                         1273
# 4      80100      92415          21801  ...                          455
#
#    여성연령대_60_이상_토요일시간대_4_생활인구_수  여성연령대_60_이상_토요일시간대_5_생활인구_수  \
# ...
