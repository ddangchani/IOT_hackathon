# %%
from google.colab import drive
drive.mount('/content/Mydrive')
# %cd "/content/Mydrive/MyDrive/IOT_hackathon/Github/IOT_hackathon"

# %%
# /* Python3 샘플 코드 */

import pandas as pd
import requests
import pprint
import json

# %%
# SDoT 환경정보
url = "http://api.seoulhackathon.kr/instlInfo/U2VvdWxIYWNrYXRob24yMDIy/48/1"

response = requests.get(url)
print(response.content)

contents = response.json()

# %%
df_env = pd.json_normalize(contents["result_data"])
df_env = df.loc[:,['modl_serial', 'address', 'la', 'lo']]

# %%
df_env.head()

# %%
# SDoT 유동인구 정보
url2 = "http://api.seoulhackathon.kr/instlInfo/U2VvdWxIYWNrYXRob24yMDIy/32/1"

response = requests.get(url2)
print(response.content)

contents = response.json()

# %%
df_pop = pd.json_normalize(contents["result_data"])
df_pop = df_pop.loc[:,['modl_serial', 'address', 'la', 'lo']]

# %%
df_pop.shape

# %%
df_env.to_csv('/content/Mydrive/MyDrive/IOT_hackathon/Github/IOT_hackathon/Preprocessing/전처리완료/SDoT_env_Coordinate.csv')
df_pop.to_csv('/content/Mydrive/MyDrive/IOT_hackathon/Github/IOT_hackathon/Preprocessing/전처리완료/SDoT_pop_Coordinate.csv')
